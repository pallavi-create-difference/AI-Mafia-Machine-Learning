# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_x = pd.read_csv('./Training Data/Logistic_X_Train.csv')
train_y = pd.read_csv('./Training Data/Logistic_Y_Train.csv')
test_x=pd.read_csv('./Testing Data/Logistic_X_Test.csv')
#http://localhost:8888/edit/PycharmProjects/Logistic%20Regression/Testing%20Data/Logistic_X_Test.csv

# %%
print(train_x.shape,train_y.shape)
print(test_x.shape)
# Out:
# (3000, 3) (3000, 1)
# (1000, 3)

# %%
x =train_x.values
y = train_y.values

#x = x.reshape((-1,3))
y = y.reshape((-1,))
print(x.shape)
print(y.shape)
# Out:
# (3000, 3)
# (3000,)

# %%
f1 = train_x[['f1']].values
f2 = train_x[['f2']].values
f3 = train_x[['f3']].values
print(f1.shape)
# Out:
# (3000, 1)

# %%
#pl=plt.figure()

ax = plt.axes(projection="3d")
ax.scatter(f1,y )
#ax.scatter3D(f2,f3,f1,  cmap='hsv')
plt.show()

'''
ax = plt.axes(projection="3d")

plt.show()
'''
# Out:
# '\nax = plt.axes(projection="3d")\n\nplt.show()\n'

# %%
ax = plt.axes(projection="3d")
ax.scatter3D(f2,f3,f1,  cmap='hsv')
plt.show()
